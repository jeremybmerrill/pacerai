# %% [markdown]
# we're creating two models, to take a document description (from purchase dockets) and a document casename + docuemnt_type (from RSS) to predict whether it's a search warrant or not.
#
# we're going to get the training data in several batches:
#
# 1. a bunch of docs (like 20 per district court) that ARE NOT search warrants
# 2. a bunch of docs that match the term "search" and "warrant" that are hand-coded.
# 3. a bunch of case_names from RSS
# 4. case_names from RSS that are coded -sw- in the case number.
#
# So, basically, we're oversampling on things that match "search" and "warrant". TODO: we might also want to oversample on cases with the United States as a party...
#
# #1 is on sheet "TK" of https://docs.google.com/spreadsheets/d/1gyYAlYdL9o45pPIC0POXzKwvO5Ji7SZ9uwP46uXfMqA/edit#gid=1319449048
#
# #2 is on sheet "matches search_warrants" of the same doc, https://docs.google.com/spreadsheets/d/1gyYAlYdL9o45pPIC0POXzKwvO5Ji7SZ9uwP46uXfMqA/edit#gid=1319449048
#
# #3 is on "search warrant case_names from RSS" of the same doc.

# %% [markdown]
# ## getting search warrant docs
#
# so we can oversample on things that might be search warrants

# %%
from os import environ, makedirs
from os.path import join, exists, dirname
import requests
from urllib.parse import urlencode
import logging
import csv
import pandas as pd

API_KEY = environ.get("API_KEY")
STORAGE_PATH = "pdfs/"
# Out:
# /Users/jeremybmerrill/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
def get_pdf(recap_filepath_local, type_of_file="other"):
    logging.basicConfig(level=logging.DEBUG)

    fn = recap_filepath_local.split("/")[-1]
    fp = join(STORAGE_PATH, type_of_file, fn)
    makedirs(dirname(fp), exist_ok=True)
    if exists(fp):
        return fp
    url = recap_filepath_local.replace("/storage", "https://www.courtlistener.com").replace("/sata", "https://www.courtlistener.com")
    with open(fp, 'wb') as f:
        logging.debug(f"actually getting PDF from the web {url}")
        f.write(requests.get(url).content)
    return fp

def get_search_warrant_pdf(recap_filepath_local):
    return get_pdf(recap_filepath_local, "search_warrant")

# def get_docket_entries():
#     "https://www.courtlistener.com/api/rest/v3/docket-entries/?docket__id=XXX"
def search_recap_with_url(url):
    return requests.get(url, headers = {'content-type': 'application/json', "Authorization": f"Token {API_KEY}"}).json()

def search_recap(q=None, description=None, available_only=None, suit_nature=None):
    urlparams = {
        "type": "r", # Document-oriented results from the RECAP Archive
        "available_only": "on" if available_only else "off",
        "order_by": "entry_date_filed desc"
    }
    if suit_nature: urlparams["suitNature"] = suit_nature
    if description: urlparams["description"] = description
    if q: urlparams["q"] = q # wwg1wga
    return search_recap_with_url("https://www.courtlistener.com/api/rest/v3/search/?{}".format(urlencode(urlparams)))

# %%
def find_search_warrant_documents(n=1000):
#     for each case and document, make a record (in memory or in a DB), so we don\'t duplicate
#     download the documents locally
#    ?q=&type=r&order_by=entry_date_filed%20desc&available_only=on&description=search%20warrant
    next_url = None
    records = []
    while len(records) <= n:
        if len(records) == 0:
            search_result = search_recap(description="search warrant", available_only=True)
            records += search_result["results"]
            next_url = search_result["next"]
        elif next_url:
            search_result = search_recap_with_url(next_url)
            records += search_result["results"]
            next_url = search_result["next"]
        else: # next_url is not None (and it's not the first go)
            break
    return records

# %%
search_results = find_search_warrant_documents()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-4921c5c9694a> in <module>
# ----> 1 search_results = find_search_warrant_documents()
#
# <ipython-input-18-cfa4833c5c01> in find_search_warrant_documents(n)
#      11             next_url = search_result["next"]
#      12         elif next_url:
# ---> 13             search_result = search_recap_with_url(next_url)
#      14             records += search_result["results"]
#      15             next_url = search_result["next"]
#
# <ipython-input-17-5df17cb8b2be> in search_recap_with_url(url)
#      19 #     "https://www.courtlistener.com/api/rest/v3/docket-entries/?docket__id=XXX"
#      20 def search_recap_with_url(url):
# ---> 21     return requests.get(url, headers = {'content-type': 'application/json', "Authorization": f"Token {API_KEY}"}).json()
#      22
#      23 def search_recap(q=None, description=None, available_only=None, suit_nature=None):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/http/client.py in getresponse(self)
#    1320         try:
#    1321             try:
# -> 1322                 response.begin()
#    1323             except ConnectionError:
#    1324                 self.close()
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
SEARCH_WARRANT_CSV_FN = 'search_warrants_model/search_warrants.csv'

with open(SEARCH_WARRANT_CSV_FN, 'w') as csvfile:
    writer = None
    for i, result in enumerate(search_results):
        if i == 0:
            writer = csv.DictWriter(csvfile, fieldnames=result.keys())
            writer.writeheader()
        writer.writerow(result)
        get_search_warrant_pdf(result["filepath_local"])

# %% [markdown]
# # get non-search warrants (negative training data)

# %%
import courtlistener
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-ba3c5b9c86de> in <module>
# ----> 1 import courtlistener
#
# ModuleNotFoundError: No module named 'courtlistener'

# %%
def get_courts():
    """
    kwargs passed through to search_recap:  q=None, description=None, available_only=None, suit_nature=None, filed_after=None

    """
    next_url = None
    records = []
    while True:
        if len(records) == 0:
            search_result = search_recap_with_url("https://www.courtlistener.com/api/rest/v3/courts/")
            records += search_result["results"]
            next_url = search_result["next"]
        elif next_url:
            search_result = search_recap_with_url(next_url)
            records += search_result["results"]
            next_url = search_result["next"]
        else:  # next_url is not None (and it's not the first go)
            break
    return records

courts = get_courts()

# %%
courts = pd.DataFrame(courts)
district_courts = courts[(~courts["fjc_court_id"].isna()) & (courts["fjc_court_id"] != '') & (courts["id"].str.match(r"[a-z]{2,3}d$"))]
district_courts
# Out:
#                                           resource_uri    id  pacer_court_id  \
# 140  https://www.courtlistener.com/api/rest/v3/cour...   dcd            45.0
# 142  https://www.courtlistener.com/api/rest/v3/cour...  almd            17.0
# 143  https://www.courtlistener.com/api/rest/v3/cour...  alnd            19.0
# 144  https://www.courtlistener.com/api/rest/v3/cour...  alsd            21.0
# 145  https://www.courtlistener.com/api/rest/v3/cour...   akd            23.0
# ..                                                 ...   ...             ...
# 259  https://www.courtlistener.com/api/rest/v3/cour...   wyd           207.0
# 261  https://www.courtlistener.com/api/rest/v3/cour...   gud            59.0
# 262  https://www.courtlistener.com/api/rest/v3/cour...  nmid           139.0
# 263  https://www.courtlistener.com/api/rest/v3/cour...   prd           159.0
# 264  https://www.courtlistener.com/api/rest/v3/cour...   vid           193.0
#
#     pacer_has_rss_feed  pacer_rss_entry_types date_last_pacer_contact  \
# 140               True                    all                    None
# 142               True  order,order-cr,motion                    None
# 143              False                                           None
# 144               True                    all                    None
# 145               True                    all                    None
# ..                 ...                    ...                     ...
# 259               True                    all                    None
# 261               True                    all                    None
# 262               True  order,order-cr,motion                    None
# 263               True                    all                    None
# 264               True         order,order-cr                    None
#
#     fjc_court_id                     date_modified  in_use  \
# 140           90  2020-07-27T23:10:06.610741-07:00    True
# 142           27  2020-07-27T23:18:14.673226-07:00    True
# 143           26         2013-08-14T22:35:30-07:00    True
# 144           28  2020-07-27T23:14:09.738906-07:00    True
# 145           7-  2020-07-27T23:15:10.762327-07:00    True
# ..           ...                               ...     ...
# 259           89  2020-07-27T23:15:13.163424-07:00    True
# 261           93  2020-07-27T23:10:05.257570-07:00    True
# 262           94  2020-07-27T23:14:09.655978-07:00    True
# 263           04  2020-07-27T23:18:16.151084-07:00    True
# 264           91  2020-07-27T23:18:14.822160-07:00    True
#
#      has_opinion_scraper  has_oral_argument_scraper  position citation_string  \
# 140                 True                      False     200.5          D.D.C.
# 142                False                      False     201.0       M.D. Ala.
# 143                False                      False     201.5       N.D. Ala.
# 144                False                      False     202.0       S.D. Ala.
# 145                False                      False     202.5       D. Alaska
# ..                   ...                        ...       ...             ...
# 259                False                      False     299.0         D. Wyo.
# 261                False                      False     299.3         D. Guam
# 262                False                      False     299.4      N. Mar. I.
# 263                False                      False     299.5          D.P.R.
# 264                False                      False     299.9          D.V.I.
#
#                    short_name                                 full_name  \
# 140      District of Columbia      District Court, District of Columbia
# 142              M.D. Alabama              District Court, M.D. Alabama
# 143              N.D. Alabama              District Court, N.D. Alabama
# 144              S.D. Alabama              District Court, S.D. Alabama
# 145                 D. Alaska                 District Court, D. Alaska
# ..                        ...                                       ...
# 259                D. Wyoming                District Court, D. Wyoming
# 261                   D. Guam                   District Court, D. Guam
# 262  Northern Mariana Islands  District Court, Northern Mariana Islands
# 263            D. Puerto Rico            District Court, D. Puerto Rico
# 264            Virgin Islands            District Court, Virgin Islands
#
#                                url start_date end_date jurisdiction
# 140   http://www.dcd.uscourts.gov/       None     None           FD
# 142  http://www.almd.uscourts.gov/       None     None           FD
# 143  http://www.alnd.uscourts.gov/       None     None           FD
# 144   http://www.als.uscourts.gov/       None     None           FD
# 145   http://www.akd.uscourts.gov/       None     None           FD
# ..                             ...        ...      ...          ...
# 259   http://www.wyd.uscourts.gov/       None     None           FD
# 261   http://www.gud.uscourts.gov/       None     None           FD
# 262  http://www.nmid.uscourts.gov/       None     None           FD
# 263   http://www.prd.uscourts.gov/       None     None           FD
# 264   http://www.vid.uscourts.gov/       None     None           FD
#
# [94 rows x 19 columns]

# %%
def get_documents_by_court(court, available_only=True, filed_after=None, party_name=None):
    urlparams = {
        "type": "r",  # Document-oriented results from the RECAP Archive
        "order_by": "entry_date_filed desc",
    }
    if available_only:
        urlparams["available_only"] = "on"
    if filed_after:
        urlparams["filed_after"] = filed_after
    if court:
        urlparams["court"] = court
    if party_name:
        urlparams["party_name"] = party_name
    return search_recap_with_url(
        "https://www.courtlistener.com/api/rest/v3/search/?{}".format(
            urlencode(urlparams)
        )
    )

get_documents_by_court("gand")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gand HTTP/1.1" 200 None
# {'count': 41279,
#  'next': 'https://www.courtlistener.com/api/rest/v3/search/?available_only=on&court=gand&order_by=entry_date_filed+desc&page=2&type=r',
#  'previous': None,
#  'results': [{'absolute_url': '/docket/18241602/82/elite-integrated-medical-llc-v-new-world-communicatons-of-atlanta-inc/',
#    'assignedTo': 'Amy Mil Totenberg',
#    'assigned_to_id': 3247,
#    'attachment_number': None,
#    'attorney': None,
#    'attorney_id': None,
#    'caseName': 'Elite Integrated Medical, LLC v. New World Communicatons of Atlanta, Inc.',
#    'cause': '',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2019-11-17T23:53:00-08:00',
#    'dateTerminated': '2021-04-28T00:53:00-07:00',
#    'description': '',
#    'docketNumber': '1:19-cv-05214',
#    'docket_absolute_url': '/docket/18241602/elite-integrated-medical-llc-v-new-world-communicatons-of-atlanta-inc/',
#    'docket_entry_id': 163057445,
#    'docket_id': 18241602,
#    'document_number': 82,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-28T00:53:00-07:00',
#    'entry_number': 82,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.270943/gov.uscourts.gand.270943.82.0.pdf',
#    'firm': None,
#    'firm_id': None,
#    'id': 168226750,
#    'is_available': True,
#    'jurisdictionType': 'Diversity of citizenship',
#    'juryDemand': '',
#    'page_count': 26,
#    'party': None,
#    'party_id': None,
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': 'Order on Motion to Dismiss',
#    'snippet': '\n\n    \n    28 April 2021\n\n\n\n\nPACER Document\n          Case 1:19-cv-05214-AT Document 82 Filed 04/28/21 Page 1 of 26\n\n\n\n\n                     IN THE UNITED STATES DISTRICT COURT\n                    FOR THE NORTHERN DISTRICT OF GEORGIA\n                              ATLANTA DIVISION\n\n\n    ELITE INTEGRATED MEDICAL,                       :\n    LLC, f/k/a SUPERIOR HEALTHCARE                  :\n    OF WOODSTOCK, LLC (d/b/a                        :\n    SUPERIOR HEALTHCARE GROUP),                     :\n ',
#    'suitNature': '360 Other personal liability',
#    'timestamp': '2021-04-29T05:27:58.750000-07:00'},
#   {'absolute_url': '/docket/59856513/13/united-states-v-hill/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': None,
#    'attorney': ['Brent A. Gray', 'Drew Findling', 'Bret Reed Hobson'],
#    'attorney_id': [7004130, 7003846, 7003847],
#    'caseName': 'United States v. Hill',
#    'cause': '',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-19T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': '',
#    'docketNumber': '1:21-cr-00143',
#    'docket_absolute_url': '/docket/59856513/united-states-v-hill/',
#    'docket_entry_id': 163037724,
#    'docket_id': 59856513,
#    'document_number': 13,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-28T00:53:00-07:00',
#    'entry_number': 13,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289292/gov.uscourts.gand.289292.13.0.pdf',
#    'firm': ['Office of the United States Attorney-ATL600, Northern District of Georgia, 600 United States Courthouse'],
#    'firm_id': [286070],
#    'id': 168206801,
#    'is_available': True,
#    'jurisdictionType': '',
#    'juryDemand': '',
#    'page_count': 20,
#    'party': ['Victor Hill', 'USA'],
#    'party_id': [10685645, 10685646],
#    'referredTo': 'Christopher C. Bly',
#    'referred_to_id': 9190,
#    'short_description': 'Pretrial Scheduling Order',
#    'snippet': '\n\n    \n    28 April 2021\n\n\n\n\nPACER Document\nCase 1:21-cr-00143-ELR-CCB Document 13 Filed 04/28/21 Page 1 of 20\n\n\n\n\n               IN THE UNITED STATES DISTRICT COURT\n              FOR THE NORTHERN DISTRICT OF GEORGIA\n                         ATLANTA DIVISION\n\nUNITED STATES OF AMERICA\n\nv.                                           CRIMINAL ACTION FILE NO.\n\nVICTOR HILL,                                 1:21-CR-143-ELR-CCB\n\n                                             [Eff. 12/01/2020]\n     Defendant',
#    'suitNature': '',
#    'timestamp': '2021-04-28T20:32:19.902000-07:00'},
#   {'absolute_url': '/docket/18410814/46/mason-v-sony-pictures-entertainment-inc/',
#    'assignedTo': 'Steven D. Grimberg',
#    'assigned_to_id': None,
#    'attachment_number': None,
#    'attorney': ['Joel Benjamin Rothman',
#     'Marissa B. Lewis',
#     'Elaine K. Kim',
#     'Caroline Johnson Tanner'],
#    'attorney_id': [6554752, 6554753, 6621363, 6621364],
#    'caseName': 'Mason v. Sony Pictures Entertainment Inc.',
#    'cause': '28:1338 Copyright Infringement',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2020-09-01T00:53:00-07:00',
#    'dateTerminated': '2021-04-28T00:53:00-07:00',
#    'description': '',
#    'docketNumber': '1:20-cv-03616',
#    'docket_absolute_url': '/docket/18410814/mason-v-sony-pictures-entertainment-inc/',
#    'docket_entry_id': 163132515,
#    'docket_id': 18410814,
#    'document_number': 46,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-28T00:53:00-07:00',
#    'entry_number': 46,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.280892/gov.uscourts.gand.280892.46.0.pdf',
#    'firm': ['Holland & Knight LLP -Atl',
#     'Mitchell Silberberg & Knupp, LLP - NY',
#     'Mitchell Silberberg & Knupp, LLP -LA'],
#    'firm_id': [251521, 646259, 646260],
#    'id': 168302732,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'Plaintiff',
#    'page_count': 18,
#    'party': ['Sony Pictures Entertainment Inc.',
#     'Eric E. Kripke',
#     'Bryan Zack Mason',
#     'Sony Pictures Television Inc.',
#     'NBCUniversal Media, LLC'],
#    'party_id': [9970336, 9970337, 9970338, 9970339, 9970335],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': 'Order on Motion to Dismiss',
#    'snippet': '\n\n    \n    28 April 2021\n\n\n\n\nPACER Document\n       Case 1:20-cv-03616-SDG Document 46 Filed 04/28/21 Page 1 of 18\n\n\n\n\n                IN THE UNITED STATES DISTRICT COURT\n               FOR THE NORTHERN DISTRICT OF GEORGIA\n                         ATLANTA DIVISION\n\nBRYAN ZACK MASON,\n\n       Plaintiff,\n                       v.\nSONY PICTURES ENTERTAINMENT, INC.,                         Civil Action No.\nSONY PICTURES TELEVISION INC.,                            1:20-cv-03616-SDG\nNBCUNIVERSAL MEDIA, ',
#    'suitNature': '820 Copyright',
#    'timestamp': '2021-04-29T13:22:51.116999-07:00'},
#   {'absolute_url': '/docket/59863862/1/turner-v-valentino-usa-inc/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': None,
#    'attorney': ['Mario Bernard Williams'],
#    'attorney_id': [7005296],
#    'caseName': 'Turner v. Valentino USA, Inc.',
#    'cause': '42:1981 Race Discrimination',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-27T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'COMPLAINT with Jury Demand filed by Dana Turner. (Filing fee $402.00, receipt number AGANDC-10932146) (Attachments: # 1 Exhibit - Declaration of Ms. Hall, # 2 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/28/2021)',
#    'docketNumber': '1:21-cv-01739',
#    'docket_absolute_url': '/docket/59863862/turner-v-valentino-usa-inc/',
#    'docket_entry_id': 163052875,
#    'docket_id': 59863862,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-27T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289714/gov.uscourts.gand.289714.1.0.pdf',
#    'firm': None,
#    'firm_id': None,
#    'id': 168222050,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'Plaintiff',
#    'page_count': 21,
#    'party': ['Valentino USA, Inc.', 'Dana Turner', 'Katie Dow'],
#    'party_id': [10687491, 10687492, 10687493],
#    'referredTo': 'Catherine M. Salinas',
#    'referred_to_id': 9196,
#    'short_description': '',
#    'snippet': '\n\n    COMPLAINT with Jury Demand filed by Dana Turner. (Filing fee $402.00, receipt number AGANDC-10932146) (Attachments: # 1 Exhibit - Declaration of Ms. Hall, # 2 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/28/2021)\n    27 April 2021\n\n\n\n\nPACER Document\n     Case 1:21-cv-01739-ELR-CMS Document 1 Fil',
#    'suitNature': '442 Civil Rights: Jobs',
#    'timestamp': '2021-04-29T01:17:44.076000-07:00'},
#   {'absolute_url': '/docket/59863861/1/britton-v-vishal-river-shoals-llc/',
#    'assignedTo': 'Mark Howard Cohen',
#    'assigned_to_id': 666,
#    'attachment_number': None,
#    'attorney': ['Craig J. Ehrlich'],
#    'attorney_id': [7005295],
#    'caseName': 'Britton v. Vishal River Shoals LLC',
#    'cause': '42:12101 et seq. Americans with Disabilities Act of 1990',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-27T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'COMPLAINT filed by Tiawan Britton. (Filing fee $402.00, receipt number AGANDC-10931721) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/28/2021)',
#    'docketNumber': '1:21-cv-01735',
#    'docket_absolute_url': '/docket/59863861/britton-v-vishal-river-shoals-llc/',
#    'docket_entry_id': 163052871,
#    'docket_id': 59863861,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-27T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289685/gov.uscourts.gand.289685.1.0.pdf',
#    'firm': ['The Law Office of Craig J. Ehrlich, LLC'],
#    'firm_id': [351567],
#    'id': 168222046,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'None',
#    'page_count': 17,
#    'party': ['Vishal River Shoals LLC', 'Tiawan Britton'],
#    'party_id': [10687489, 10687490],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': '\n\n    COMPLAINT filed by Tiawan Britton. (Filing fee $402.00, receipt number AGANDC-10931721) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/28/2021)\n    27 April 2021\n\n\n\n\nPACER Document\n        Case 1:21-cv-01735-MHC Document 1 Filed 04/27/21 Page 1 of 17\n\n\n\n\n                    IN TH',
#    'suitNature': '446 Civil Rights: Americans with Disabilities - Other',
#    'timestamp': '2021-04-29T01:17:19.207999-07:00'},
#   {'absolute_url': '/docket/59856513/11/united-states-v-hill/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': None,
#    'attorney': ['Drew Findling', 'Bret Reed Hobson', 'Brent A. Gray'],
#    'attorney_id': [7004130, 7003846, 7003847],
#    'caseName': 'United States v. Hill',
#    'cause': '',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-19T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'Unsecured Bond Entered as to Victor Hill in amount of $ 50,000.00. (adg) (Entered: 04/28/2021)',
#    'docketNumber': '1:21-cr-00143',
#    'docket_absolute_url': '/docket/59856513/united-states-v-hill/',
#    'docket_entry_id': 162972718,
#    'docket_id': 59856513,
#    'document_number': 11,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-27T00:53:00-07:00',
#    'entry_number': 11,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289292/gov.uscourts.gand.289292.11.0.pdf',
#    'firm': ['Office of the United States Attorney-ATL600, Northern District of Georgia, 600 United States Courthouse'],
#    'firm_id': [286070],
#    'id': 168140680,
#    'is_available': True,
#    'jurisdictionType': '',
#    'juryDemand': '',
#    'page_count': 2,
#    'party': ['Victor Hill', 'USA'],
#    'party_id': [10685645, 10685646],
#    'referredTo': 'Christopher C. Bly',
#    'referred_to_id': 9190,
#    'short_description': 'Bond',
#    'snippet': '\n\n    Unsecured Bond Entered as to Victor Hill in amount of $ 50,000.00. (adg) (Entered: 04/28/2021)\n    27 April 2021\n\n\n\n\nPACER Document\n                Case 1:21-cr-00143-ELR-CCB Document 11 Filed 04/27/21 Page 1 of 2\n&#x27;AO         98        (Rev.             12/11)                Appearance                              Bond               Page               1\n\n\n\n                                   UNITED STATES DISTRICT COURT\n                                                                  ',
#    'suitNature': '',
#    'timestamp': '2021-04-28T20:32:08.012999-07:00'},
#   {'absolute_url': '/docket/59856513/12/united-states-v-hill/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': None,
#    'attorney': ['Drew Findling', 'Bret Reed Hobson', 'Brent A. Gray'],
#    'attorney_id': [7004130, 7003846, 7003847],
#    'caseName': 'United States v. Hill',
#    'cause': '',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-19T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'ORDER Setting Conditions of Release as to Victor Hill. Signed by Magistrate Judge Russell G. Vineyard on 4/27/2021. (adg) (Entered: 04/28/2021)',
#    'docketNumber': '1:21-cr-00143',
#    'docket_absolute_url': '/docket/59856513/united-states-v-hill/',
#    'docket_entry_id': 162972719,
#    'docket_id': 59856513,
#    'document_number': 12,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-27T00:53:00-07:00',
#    'entry_number': 12,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289292/gov.uscourts.gand.289292.12.0.pdf',
#    'firm': ['Office of the United States Attorney-ATL600, Northern District of Georgia, 600 United States Courthouse'],
#    'firm_id': [286070],
#    'id': 168140681,
#    'is_available': True,
#    'jurisdictionType': '',
#    'juryDemand': '',
#    'page_count': 4,
#    'party': ['Victor Hill', 'USA'],
#    'party_id': [10685645, 10685646],
#    'referredTo': 'Christopher C. Bly',
#    'referred_to_id': 9190,
#    'short_description': 'Order Setting Conditions of Release',
#    'snippet': '\n\n    ORDER Setting Conditions of Release as to Victor Hill. Signed by Magistrate Judge Russell G. Vineyard on 4/27/2021. (adg) (Entered: 04/28/2021)\n    27 April 2021\n\n\n\n\nPACER Document\n                Case 1:21-cr-00143-ELR-CCB Document 12 Filed 04/27/21 Page 1 of 4\n\nAO 199A (Rev. 12/11) Order Setting Conditions of Release Page 1 of 4 Pases\n\n\n\n\n                                  UNITED STATES DISTRICT COURT FILED i\n                                                            for the U-S&#x27;3.^',
#    'suitNature': '',
#    'timestamp': '2021-04-28T20:32:08.012999-07:00'},
#   {'absolute_url': '/docket/59859467/8/barnes-v-teva-pharmaceuticals-usa/',
#    'assignedTo': None,
#    'assigned_to_id': None,
#    'attachment_number': None,
#    'attorney': None,
#    'attorney_id': None,
#    'caseName': 'Barnes v. Teva Pharmaceuticals, USA',
#    'cause': '28:1332 Diversity-Product Liability',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': None,
#    'dateTerminated': None,
#    'description': ' MDL CONDITIONAL TRANSFER ORDER (CTO 16) MDL 2974: Transferring case to the U.S. District Court, Northern District of Georgia (Atlanta). Signed by The Judicial Panel on  Multidistrict Litigation, on 04/26/2021  (jlmS, COURT STAFF) (Filed on 4/26/2021) [Transferred from California Northern on 4/26/2021.]',
#    'docketNumber': '1:21-cv-01700-LMM',
#    'docket_absolute_url': '/docket/59859467/barnes-v-teva-pharmaceuticals-usa/',
#    'docket_entry_id': 162927373,
#    'docket_id': 59859467,
#    'document_number': 8,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-26T00:53:00-07:00',
#    'entry_number': 8,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289588/gov.uscourts.gand.289588.8.0.pdf',
#    'firm': None,
#    'firm_id': None,
#    'id': 168094649,
#    'is_available': True,
#    'jurisdictionType': '',
#    'juryDemand': '',
#    'page_count': 3,
#    'party': None,
#    'party_id': None,
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': '\n\n     MDL CONDITIONAL TRANSFER ORDER (CTO 16) MDL 2974: Transferring case to the U.S. District Court, Northern District of Georgia (Atlanta). Signed by The Judicial Panel on  Multidistrict Litigation, on 04/26/2021  (jlmS, COURT STAFF) (Filed on 4/26/2021) [Transferred from California Northern on 4/26/2021.]\n    26 April 2021\n\n\n\n\nPACER Document\n       Case\n        Case1:20-md-02974-LMM\n             1:21-cv-01700-LMM Document 84 Filed04/26/21\n                                        8 Filed  04/2',
#    'suitNature': 'Personal Injury: Health Care/Pharmaceutical Personal Injury Product Liability',
#    'timestamp': '2021-04-28T01:36:16.954000-07:00'},
#   {'absolute_url': '/docket/59859548/1/britton-v-samples/',
#    'assignedTo': 'Beverly Baldwin Martin',
#    'assigned_to_id': 2056,
#    'attachment_number': None,
#    'attorney': ['Craig J. Ehrlich'],
#    'attorney_id': [7003345],
#    'caseName': 'Britton v. Samples',
#    'cause': '42:12101 et seq. Americans with Disabilities Act of 1990',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-26T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'COMPLAINT filed by Tiawan Britton. (Filing fee $402.00, receipt number AGANDC-10928129) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/27/2021)',
#    'docketNumber': '1:21-cv-01712',
#    'docket_absolute_url': '/docket/59859548/britton-v-samples/',
#    'docket_entry_id': 162927812,
#    'docket_id': 59859548,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-26T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289626/gov.uscourts.gand.289626.1.0.pdf',
#    'firm': ['The Law Office of Craig J. Ehrlich, LLC'],
#    'firm_id': [351567],
#    'id': 168095128,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'None',
#    'page_count': 12,
#    'party': ['Tiawan Britton', 'Faye A. Samples'],
#    'party_id': [10685073, 10685076],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': '\n\n    COMPLAINT filed by Tiawan Britton. (Filing fee $402.00, receipt number AGANDC-10928129) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/27/2021)\n    26 April 2021\n\n\n\n\nPACER Document\n        Case 1:21-cv-01712-LMM Document 1 Filed 04/26/21 Page 1 of 12\n\n\n\n\n                    IN TH',
#    'suitNature': '446 Civil Rights: Americans with Disabilities - Other',
#    'timestamp': '2021-04-28T01:13:37.874000-07:00'},
#   {'absolute_url': '/docket/59859550/1/gans-llc-v-apaxx-inc/',
#    'assignedTo': 'Mark Howard Cohen',
#    'assigned_to_id': 666,
#    'attachment_number': None,
#    'attorney': ['Sabrina Lynn Atkins', 'Frederick Owen Ferrand'],
#    'attorney_id': [7003352, 7003351],
#    'caseName': 'Gans, LLC v. Apaxx, Inc.',
#    'cause': '28:1332 Diversity-Breach of Contract',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-26T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'COMPLAINT with Jury Demand filed by Gans, LLC. (Filing fee $402.00, receipt number AGANDC-10928421) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/27/2021)',
#    'docketNumber': '1:21-cv-01714',
#    'docket_absolute_url': '/docket/59859550/gans-llc-v-apaxx-inc/',
#    'docket_entry_id': 162927821,
#    'docket_id': 59859550,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-26T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289628/gov.uscourts.gand.289628.1.0.pdf',
#    'firm': ['Swift Currie McGhee & Hiers',
#     'Swift, Currie, McGhee & Hiers, LLP'],
#    'firm_id': [84184, 356180],
#    'id': 168095137,
#    'is_available': True,
#    'jurisdictionType': 'Diversity',
#    'juryDemand': 'Plaintiff',
#    'page_count': 18,
#    'party': ['Apaxx, Inc.', 'Gans, LLC'],
#    'party_id': [10685081, 10685083],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': '\n\n    COMPLAINT with Jury Demand filed by Gans, LLC. (Filing fee $402.00, receipt number AGANDC-10928421) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/27/2021)\n    26 April 2021\n\n\n\n\nPACER Document\n         Case 1:21-cv-01714-MHC Document 1 Filed 04/26/21 Page 1 of 18\n\n\n\n\n            ',
#    'suitNature': '190 Contract: Other',
#    'timestamp': '2021-04-28T01:14:13.695000-07:00'},
#   {'absolute_url': '/docket/59859549/1/wages-v-lily-transportation-corp/',
#    'assignedTo': 'Richard W. Story',
#    'assigned_to_id': 3119,
#    'attachment_number': None,
#    'attorney': ['Grace A. Starling', 'Victor Severin Roberts'],
#    'attorney_id': [7003349, 7003350],
#    'caseName': 'Wages v. Lily Transportation, Corp.',
#    'cause': '29:203 Equal Pay Act',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-26T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'COMPLAINT with Jury Demand filed by Mae Wages. (Filing fee $402, receipt number AGANDC-10927135) (Attachments: # 1 Civil Cover Sheet)(dgr) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/27/2021)',
#    'docketNumber': '2:21-cv-00094',
#    'docket_absolute_url': '/docket/59859549/wages-v-lily-transportation-corp/',
#    'docket_entry_id': 162927818,
#    'docket_id': 59859549,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-26T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289630/gov.uscourts.gand.289630.1.0.pdf',
#    'firm': ['Barrett & Farahany, LLP'],
#    'firm_id': [85258],
#    'id': 168095134,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'Plaintiff',
#    'page_count': 10,
#    'party': ['Mae Wages', 'Lily Transportation, Corp.'],
#    'party_id': [10685080, 10685082],
#    'referredTo': 'James Clay Fuller',
#    'referred_to_id': 9192,
#    'short_description': '',
#    'snippet': '\n\n    COMPLAINT with Jury Demand filed by Mae Wages. (Filing fee $402, receipt number AGANDC-10927135) (Attachments: # 1 Civil Cover Sheet)(dgr) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/27/2021)\n    26 April 2021\n\n\n\n\nPACER Document\n       Case 2:21-cv-00094-RWS-JCF Document 1 Filed 04/26/21 Page 1 of 10\n\n\n\n\n             ',
#    'suitNature': '442 Civil Rights: Jobs',
#    'timestamp': '2021-04-28T01:14:40.329000-07:00'},
#   {'absolute_url': '/docket/59856513/7/united-states-v-hill/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': None,
#    'attorney': ['Drew Findling', 'Bret Reed Hobson', 'Brent A. Gray'],
#    'attorney_id': [7004130, 7003846, 7003847],
#    'caseName': 'United States v. Hill',
#    'cause': '',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-19T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'MOTION to Unseal Indictment by USA as to Victor Hill. (jpa) (Entered: 04/27/2021)',
#    'docketNumber': '1:21-cr-00143',
#    'docket_absolute_url': '/docket/59856513/united-states-v-hill/',
#    'docket_entry_id': 162844742,
#    'docket_id': 59856513,
#    'document_number': 7,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-26T00:53:00-07:00',
#    'entry_number': 7,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289292/gov.uscourts.gand.289292.7.0_1.pdf',
#    'firm': ['Office of the United States Attorney-ATL600, Northern District of Georgia, 600 United States Courthouse'],
#    'firm_id': [286070],
#    'id': 168010741,
#    'is_available': True,
#    'jurisdictionType': '',
#    'juryDemand': '',
#    'page_count': 1,
#    'party': ['Victor Hill', 'USA'],
#    'party_id': [10685645, 10685646],
#    'referredTo': 'Christopher C. Bly',
#    'referred_to_id': 9190,
#    'short_description': 'Motion to Unseal Document',
#    'snippet': '\n\n    MOTION to Unseal Indictment by USA as to Victor Hill. (jpa) (Entered: 04/27/2021)\n    26 April 2021\n\n\n\n\nPACER Document\n      Case 1:21-cr-00143-UNA Document 7 Filed 04/26/21 Page 1 of 1\n\n\n                                                                        Fte^,\n                                                                         °^^ys\n                                                                        APR26^,\n                                                                ^ES^r',
#    'suitNature': '',
#    'timestamp': '2021-04-28T20:32:08.012999-07:00'},
#   {'absolute_url': '/docket/59856513/8/united-states-v-hill/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': None,
#    'attorney': ['Drew Findling', 'Bret Reed Hobson', 'Brent A. Gray'],
#    'attorney_id': [7004130, 7003846, 7003847],
#    'caseName': 'United States v. Hill',
#    'cause': '',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-19T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'ORDER granting 7 Motion to Unseal Indictment as to Victor Hill (1).. Signed by Magistrate Judge Russell G. Vineyard on 4/26/21. (jpa) (Entered: 04/27/2021)',
#    'docketNumber': '1:21-cr-00143',
#    'docket_absolute_url': '/docket/59856513/united-states-v-hill/',
#    'docket_entry_id': 162844743,
#    'docket_id': 59856513,
#    'document_number': 8,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-26T00:53:00-07:00',
#    'entry_number': 8,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289292/gov.uscourts.gand.289292.8.0_1.pdf',
#    'firm': ['Office of the United States Attorney-ATL600, Northern District of Georgia, 600 United States Courthouse'],
#    'firm_id': [286070],
#    'id': 168010742,
#    'is_available': True,
#    'jurisdictionType': '',
#    'juryDemand': '',
#    'page_count': 1,
#    'party': ['Victor Hill', 'USA'],
#    'party_id': [10685645, 10685646],
#    'referredTo': 'Christopher C. Bly',
#    'referred_to_id': 9190,
#    'short_description': 'Order on Motion to Unseal Document',
#    'snippet': '\n\n    ORDER granting 7 Motion to Unseal Indictment as to Victor Hill (1).. Signed by Magistrate Judge Russell G. Vineyard on 4/26/21. (jpa) (Entered: 04/27/2021)\n    26 April 2021\n\n\n\n\nPACER Document\n       Case 1:21-cr-00143-UNA Document 8 Filed 04/26/21 Page 1 of 1\n                                                                       %MCHAMBER$\n                                                                        u-S.D.C:Atiante&quot;\n\n                                                        ',
#    'suitNature': '',
#    'timestamp': '2021-04-28T20:32:08.012999-07:00'},
#   {'absolute_url': '/docket/8021495/110/georgia-coalition-for-the-peoples-agenda-inc-v-raffensperger/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': None,
#    'attorney': ['Phi Nguyen',
#     'Bryan Ludington Sells',
#     'Bryan Francis Jacoutot',
#     'Danielle M. Lang',
#     'Julie Marie Houk',
#     'Ezra David Rosenberg',
#     'Bryan P. Tyson',
#     'Jonathan Diaz',
#     'Diane Festin LaRoss',
#     'J. Gerald Hebert',
#     'Loree Anne Paradise',
#     'Jon M. Greenbaum',
#     'Vilia Hayes',
#     'Kristen Clarke',
#     'John Michael Powers',
#     'Cristina Correia',
#     'Gregory Farrell',
#     'Mark P. Gaber'],
#    'attorney_id': [3266624,
#     3266625,
#     3266626,
#     3266627,
#     3266628,
#     3266629,
#     3266630,
#     3266631,
#     6488556,
#     6393363,
#     6393364,
#     6393365,
#     6393366,
#     3266619,
#     3266620,
#     3266621,
#     3266622,
#     3266623],
#    'caseName': "Georgia Coalition for the Peoples' Agenda, Inc. v. Raffensperger",
#    'cause': '52:10301 Denial or abridgement of right to vote on account of race or color',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2018-10-11T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'STIPULATION of Dismissal by Georgia State Conference of the NAACP, The Joseph and Evelyn Lowery Institute for Justice and Human Rights, Inc.. (Attachments: # 1 Text of Proposed Order)(Sells, Bryan) (Entered: 04/23/2021)',
#    'docketNumber': '1:18-cv-04727',
#    'docket_absolute_url': '/docket/8021495/georgia-coalition-for-the-peoples-agenda-inc-v-raffensperger/',
#    'docket_entry_id': 162906454,
#    'docket_id': 8021495,
#    'document_number': 110,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-23T00:53:00-07:00',
#    'entry_number': 110,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.256344/gov.uscourts.gand.256344.110.0.pdf',
#    'firm': ["Lawyer's Committee for Civil Rights Under Law",
#     'Taylor English Duma LLP',
#     'Asian Americans Advancing Justice Atlanta',
#     'Georgia Department of Law, Department of Law',
#     "Lawyers' Committee for Civil Rights Under Law",
#     'Danielle M. Lang',
#     'The Law Office of Bryan L. Sells, LLC',
#     "Attorney General's Office-Atl, Department of Law",
#     'J. Gerald Hebert',
#     'Mark P. Gaber'],
#    'firm_id': [85121,
#     275459,
#     364517,
#     348838,
#     362120,
#     362121,
#     362122,
#     85769,
#     639344,
#     4561],
#    'id': 168073136,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'None',
#    'page_count': 4,
#    'party': ['The Joseph and Evelyn Lowery Institute for  Justice and Human Rights, Inc.',
#     'Brad Raffensperger',
#     'Asian Americans Advancing Justice-Atlanta, Inc.',
#     'Common Cause',
#     'New Georgia Project, Inc.',
#     "Georgia Coalition for the Peoples' Agenda, Inc.",
#     'Judith Martinez Cruz',
#     'Georgia State Conference of the NAACP',
#     'Georgia Association of Latino Elected Officials, Inc.',
#     'ProGeorgia State Table, Inc.'],
#    'party_id': [4864353,
#     4361570,
#     4361571,
#     4361572,
#     4361573,
#     4361574,
#     4361575,
#     4361576,
#     4361577,
#     9839731],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': '\n\n    STIPULATION of Dismissal by Georgia State Conference of the NAACP, The Joseph and Evelyn Lowery Institute for Justice and Human Rights, Inc.. (Attachments: # 1 Text of Proposed Order)(Sells, Bryan) (Entered: 04/23/2021)\n    23 April 2021\n\n\n\n\nPACER Document\n       Case 1:18-cv-04727-ELR Document 110 Filed 04/23/21 Page 1 of 4\n\n\n\n\n              IN THE UNITED STATES DISTRICT COURT\n             FOR THE NORTHERN DISTRICT OF GEORGIA\n                        ATLANTA DIVISION\n\nGEORGIA COALITION FOR',
#    'suitNature': '441 Civil Rights: Voting',
#    'timestamp': '2021-04-28T05:08:51.067999-07:00'},
#   {'absolute_url': '/docket/8021495/110/1/georgia-coalition-for-the-peoples-agenda-inc-v-raffensperger/',
#    'assignedTo': 'Eleanor Louise Ross',
#    'assigned_to_id': 2787,
#    'attachment_number': 1,
#    'attorney': ['Ezra David Rosenberg',
#     'J. Gerald Hebert',
#     'Danielle M. Lang',
#     'Jonathan Diaz',
#     'Mark P. Gaber',
#     'Kristen Clarke',
#     'Bryan Francis Jacoutot',
#     'Bryan Ludington Sells',
#     'Loree Anne Paradise',
#     'Jon M. Greenbaum',
#     'Diane Festin LaRoss',
#     'Julie Marie Houk',
#     'Phi Nguyen',
#     'Cristina Correia',
#     'Vilia Hayes',
#     'John Michael Powers',
#     'Gregory Farrell',
#     'Bryan P. Tyson'],
#    'attorney_id': [3266624,
#     3266625,
#     3266626,
#     3266627,
#     3266628,
#     3266629,
#     3266630,
#     3266631,
#     6488556,
#     6393363,
#     6393364,
#     6393365,
#     6393366,
#     3266619,
#     3266620,
#     3266621,
#     3266622,
#     3266623],
#    'caseName': "Georgia Coalition for the Peoples' Agenda, Inc. v. Raffensperger",
#    'cause': '52:10301 Denial or abridgement of right to vote on account of race or color',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2018-10-11T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'STIPULATION of Dismissal by Georgia State Conference of the NAACP, The Joseph and Evelyn Lowery Institute for Justice and Human Rights, Inc.. (Attachments: # 1 Text of Proposed Order)(Sells, Bryan) (Entered: 04/23/2021)',
#    'docketNumber': '1:18-cv-04727',
#    'docket_absolute_url': '/docket/8021495/georgia-coalition-for-the-peoples-agenda-inc-v-raffensperger/',
#    'docket_entry_id': 162906454,
#    'docket_id': 8021495,
#    'document_number': 110,
#    'document_type': 'Attachment',
#    'entry_date_filed': '2021-04-23T00:53:00-07:00',
#    'entry_number': 110,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.256344/gov.uscourts.gand.256344.110.1.pdf',
#    'firm': ['J. Gerald Hebert',
#     'Danielle M. Lang',
#     'Mark P. Gaber',
#     "Lawyer's Committee for Civil Rights Under Law",
#     "Lawyers' Committee for Civil Rights Under Law",
#     'Asian Americans Advancing Justice Atlanta',
#     'Georgia Department of Law, Department of Law',
#     'The Law Office of Bryan L. Sells, LLC',
#     'Taylor English Duma LLP',
#     "Attorney General's Office-Atl, Department of Law"],
#    'firm_id': [85121,
#     275459,
#     364517,
#     348838,
#     362120,
#     362121,
#     362122,
#     85769,
#     639344,
#     4561],
#    'id': 168098801,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'None',
#    'page_count': 2,
#    'party': ['Georgia State Conference of the NAACP',
#     "Georgia Coalition for the Peoples' Agenda, Inc.",
#     'The Joseph and Evelyn Lowery Institute for  Justice and Human Rights, Inc.',
#     'ProGeorgia State Table, Inc.',
#     'Asian Americans Advancing Justice-Atlanta, Inc.',
#     'Brad Raffensperger',
#     'Common Cause',
#     'Georgia Association of Latino Elected Officials, Inc.',
#     'New Georgia Project, Inc.',
#     'Judith Martinez Cruz'],
#    'party_id': [4864353,
#     4361570,
#     4361571,
#     4361572,
#     4361573,
#     4361574,
#     4361575,
#     4361576,
#     4361577,
#     9839731],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': 'Text of Proposed Order',
#    'snippet': '\n\n    STIPULATION of Dismissal by Georgia State Conference of the NAACP, The Joseph and Evelyn Lowery Institute for Justice and Human Rights, Inc.. (Attachments: # 1 Text of Proposed Order)(Sells, Bryan) (Entered: 04/23/2021)\n    23 April 2021\n\n\n\n\nAttachment\n      Case 1:18-cv-04727-ELR Document 110-1 Filed 04/23/21 Page 1 of 2\n\n\n\n\n             IN THE UNITED STATES DISTRICT COURT\n            FOR THE NORTHERN DISTRICT OF GEORGIA\n                       ATLANTA DIVISION\n\nGEORGIA COALITION FOR\nTHE P',
#    'suitNature': '441 Civil Rights: Voting',
#    'timestamp': '2021-04-28T05:08:51.204999-07:00'},
#   {'absolute_url': '/docket/59859444/1/camp-v-core-community-organized-relief-effort-inc/',
#    'assignedTo': 'Steve CarMichael Jones',
#    'assigned_to_id': 1670,
#    'attachment_number': None,
#    'attorney': ['Kevin D. Fitzpatrick , Jr.', 'Charles Ronald Bridgers'],
#    'attorney_id': [7003265, 7003266],
#    'caseName': 'Camp v. CORE Community Organized Relief Effort, Inc.',
#    'cause': '38:4301 U.S. Services Employment/Reemployment Act of 1994',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-23T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': "COMPLAINT filed by Eric Camp. (Filing fee $402.00, receipt number AGANDC-10924280) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. Modified on 4/26/2021 to correct filer's name. (eop). (Entered: 04/26/2021)",
#    'docketNumber': '1:21-cv-01680',
#    'docket_absolute_url': '/docket/59859444/camp-v-core-community-organized-relief-effort-inc/',
#    'docket_entry_id': 162926915,
#    'docket_id': 59859444,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-23T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289585/gov.uscourts.gand.289585.1.0.pdf',
#    'firm': ['DeLong Caldwell Bridgers Fitzpatrick & Benjamin, LLC'],
#    'firm_id': [595674, 568534],
#    'id': 168094169,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'None',
#    'page_count': 19,
#    'party': ['CORE Community Organized Relief Effort, Inc.', 'Eric Camp'],
#    'party_id': [10684952, 10684953],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': "\n\n    COMPLAINT filed by Eric Camp. (Filing fee $402.00, receipt number AGANDC-10924280) (Attachments: # 1 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. Modified on 4/26/2021 to correct filer's name. (eop). (Entered: 04/26/2021)\n    23 April 2021\n\n\n\n\nPACER Document\n  Case 1:21-cv-01680-SCJ Document 1 Filed 04/23/21",
#    'suitNature': '442 Civil Rights: Jobs',
#    'timestamp': '2021-04-27T23:18:03.391000-07:00'},
#   {'absolute_url': '/docket/59859554/1/1/weans-v-swift-transportation-services-llc/',
#    'assignedTo': 'Beverly Baldwin Martin',
#    'assigned_to_id': 2056,
#    'attachment_number': 1,
#    'attorney': ['Matthew Peter Stone',
#     'Hannah Rhodes Moore',
#     'Shawn N. Kalfus'],
#    'attorney_id': [7003389, 7003390, 7003391],
#    'caseName': 'Weans v. Swift Transportation Services, LLC',
#    'cause': '28:1441 Petition for Removal- Motor Vehicle',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-23T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'NOTICE OF REMOVAL with COMPLAINT, filed by Swift Transportation Services, LLC. (Filing fee $ 402 receipt number AGANDC-10923896) (Attachments: # 1 Exhibit All pleadings filed in state court, # 2 Civil Cover Sheet)(rvb) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/23/2021)',
#    'docketNumber': '1:21-cv-01674',
#    'docket_absolute_url': '/docket/59859554/weans-v-swift-transportation-services-llc/',
#    'docket_entry_id': 162928260,
#    'docket_id': 59859554,
#    'document_number': 1,
#    'document_type': 'Attachment',
#    'entry_date_filed': '2021-04-23T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289541/gov.uscourts.gand.289541.1.1.pdf',
#    'firm': ['Cambre & Associates, LLC', 'Stone Kalfus LLP'],
#    'firm_id': [607544, 654369],
#    'id': 168095603,
#    'is_available': True,
#    'jurisdictionType': 'Diversity',
#    'juryDemand': 'Both',
#    'page_count': 85,
#    'party': ['Neena Lee Weans',
#     'John Doe Corporations 1-5',
#     'Swift Transportation Services, LLC'],
#    'party_id': [10685136, 10685137, 10685138],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': 'Exhibit All pleadings filed in state court',
#    'snippet': '\n\n    NOTICE OF REMOVAL with COMPLAINT, filed by Swift Transportation Services, LLC. (Filing fee $ 402 receipt number AGANDC-10923896) (Attachments: # 1 Exhibit All pleadings filed in state court, # 2 Civil Cover Sheet)(rvb) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/23/2021)\n    23 April 2021\n\n\n\n\nAttachment\nCase 1:21-cv-0',
#    'suitNature': '350 Motor Vehicle',
#    'timestamp': '2021-04-28T01:08:01.516000-07:00'},
#   {'absolute_url': '/docket/59859554/1/weans-v-swift-transportation-services-llc/',
#    'assignedTo': 'Beverly Baldwin Martin',
#    'assigned_to_id': 2056,
#    'attachment_number': None,
#    'attorney': ['Hannah Rhodes Moore',
#     'Shawn N. Kalfus',
#     'Matthew Peter Stone'],
#    'attorney_id': [7003389, 7003390, 7003391],
#    'caseName': 'Weans v. Swift Transportation Services, LLC',
#    'cause': '28:1441 Petition for Removal- Motor Vehicle',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-23T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'NOTICE OF REMOVAL with COMPLAINT, filed by Swift Transportation Services, LLC. (Filing fee $ 402 receipt number AGANDC-10923896) (Attachments: # 1 Exhibit All pleadings filed in state court, # 2 Civil Cover Sheet)(rvb) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/23/2021)',
#    'docketNumber': '1:21-cv-01674',
#    'docket_absolute_url': '/docket/59859554/weans-v-swift-transportation-services-llc/',
#    'docket_entry_id': 162928260,
#    'docket_id': 59859554,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-23T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289541/gov.uscourts.gand.289541.1.0.pdf',
#    'firm': ['Stone Kalfus LLP', 'Cambre & Associates, LLC'],
#    'firm_id': [607544, 654369],
#    'id': 168095599,
#    'is_available': True,
#    'jurisdictionType': 'Diversity',
#    'juryDemand': 'Both',
#    'page_count': 5,
#    'party': ['Neena Lee Weans',
#     'John Doe Corporations 1-5',
#     'Swift Transportation Services, LLC'],
#    'party_id': [10685136, 10685137, 10685138],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': '\n\n    NOTICE OF REMOVAL with COMPLAINT, filed by Swift Transportation Services, LLC. (Filing fee $ 402 receipt number AGANDC-10923896) (Attachments: # 1 Exhibit All pleadings filed in state court, # 2 Civil Cover Sheet)(rvb) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/23/2021)\n    23 April 2021\n\n\n\n\nPACER Document\n          ',
#    'suitNature': '350 Motor Vehicle',
#    'timestamp': '2021-04-28T01:08:33.343000-07:00'},
#   {'absolute_url': '/docket/59863863/1/hernandez-v-affordable-landscaping-services-llc/',
#    'assignedTo': 'Steve CarMichael Jones',
#    'assigned_to_id': 1670,
#    'attachment_number': None,
#    'attorney': ['Jeremy Stephens', 'C. Ryan Morgan'],
#    'attorney_id': [7005323, 7005324],
#    'caseName': 'Hernandez v. Affordable Landscaping Services, LLC',
#    'cause': '29:216(b) Labor - Minimum wage or overtime compensation',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-23T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'COMPLAINT with Jury Demand filed by Jorge Hernandez. (Filing fee $402, receipt number AGANDC-10922593) (Attachments: # 1 Civil Cover Sheet)(rvb) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/25/2021)',
#    'docketNumber': '1:21-cv-01659',
#    'docket_absolute_url': '/docket/59863863/hernandez-v-affordable-landscaping-services-llc/',
#    'docket_entry_id': 163052968,
#    'docket_id': 59863863,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-23T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289553/gov.uscourts.gand.289553.1.0.pdf',
#    'firm': ['Morgan & Morgan, P.A.-FL', 'Morgan & Morgan PA'],
#    'firm_id': [85961, 274981],
#    'id': 168222144,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'Plaintiff',
#    'page_count': 13,
#    'party': ['Jorge Hernandez',
#     'Affordable Landscaping Services, LLC',
#     'Nasem Aseed'],
#    'party_id': [10687528, 10687529, 10687527],
#    'referredTo': None,
#    'referred_to_id': None,
#    'short_description': '',
#    'snippet': '\n\n    COMPLAINT with Jury Demand filed by Jorge Hernandez. (Filing fee $402, receipt number AGANDC-10922593) (Attachments: # 1 Civil Cover Sheet)(rvb) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/25/2021)\n    23 April 2021\n\n\n\n\nPACER Document\n           Case 1:21-cv-01659-SCJ Document 1 Filed 04/23/21 Page 1 of 13\n\n\n\n\n       ',
#    'suitNature': '710 Labor: Fair Standards',
#    'timestamp': '2021-04-29T00:33:32.795999-07:00'},
#   {'absolute_url': '/docket/59860320/1/kirksey-v-convergent-outsourcing-inc/',
#    'assignedTo': 'Amy Mil Totenberg',
#    'assigned_to_id': 3247,
#    'attachment_number': None,
#    'attorney': ['Misty Oaks Paxton'],
#    'attorney_id': [7003917],
#    'caseName': 'Kirksey v. Convergent Outsourcing Inc.',
#    'cause': '15:1692 Fair Debt Collection Act',
#    'court': 'District Court, N.D. Georgia',
#    'court_citation_string': 'N.D. Ga.',
#    'court_exact': 'gand',
#    'court_id': 'gand',
#    'dateArgued': None,
#    'dateFiled': '2021-04-22T00:53:00-07:00',
#    'dateTerminated': None,
#    'description': 'COMPLAINT with Jury Demand filed by Maurice Kirksey. (Filing fee $402.00, receipt number AGANDC-10920377) (Attachments: # 1 Exhibit -A, # 2 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/22/2021)',
#    'docketNumber': '1:21-cv-01644',
#    'docket_absolute_url': '/docket/59860320/kirksey-v-convergent-outsourcing-inc/',
#    'docket_entry_id': 162955445,
#    'docket_id': 59860320,
#    'document_number': 1,
#    'document_type': 'PACER Document',
#    'entry_date_filed': '2021-04-22T00:53:00-07:00',
#    'entry_number': 1,
#    'filepath_local': '/storage/recap/gov.uscourts.gand.289496/gov.uscourts.gand.289496.1.0.pdf',
#    'firm': ['The Oaks Firm'],
#    'firm_id': [469960],
#    'id': 168123166,
#    'is_available': True,
#    'jurisdictionType': 'Federal Question',
#    'juryDemand': 'Plaintiff',
#    'page_count': 12,
#    'party': ['Convergent Outsourcing Inc.',
#     'John Does 1-25',
#     'Maurice Kirksey'],
#    'party_id': [10685765, 10685766, 10685767],
#    'referredTo': 'Justin S. Anand',
#    'referred_to_id': 9188,
#    'short_description': '',
#    'snippet': '\n\n    COMPLAINT with Jury Demand filed by Maurice Kirksey. (Filing fee $402.00, receipt number AGANDC-10920377) (Attachments: # 1 Exhibit -A, # 2 Civil Cover Sheet)(eop) Please visit our website at http://www.gand.uscourts.gov/commonly-used-forms to obtain Pretrial Instructions and Pretrial Associated Forms which includes the Consent To Proceed Before U.S. Magistrate form. (Entered: 04/22/2021)\n    22 April 2021\n\n\n\n\nPACER Document\n      Case 1:21-cv-01644-AT-JSA Document 1 Filed 04/22/21 Page 1 ',
#    'suitNature': '480 Consumer Credit',
#    'timestamp': '2021-04-28T08:49:17.007000-07:00'}]}

# %%
SEARCH_WARRANT_CSV_FN = 'search_warrants_model/search_warrants_all_districts_no_query.csv'
with open(SEARCH_WARRANT_CSV_FN, 'w') as csvfile:
    writer = None

    for i, district_court in district_courts.iterrows():
        search_results = get_documents_by_court(district_court["id"])["results"]
        for result in search_results:
            if not writer:
                writer = csv.DictWriter(csvfile, fieldnames=result.keys())
                writer.writeheader()
            writer.writerow(result)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=dcd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=almd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=alnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=alsd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=akd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=azd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ared HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=arwd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=cacd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=caed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=cand HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=casd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=cod HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ctd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ded HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=flmd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=flnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=flsd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gamd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gand HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gasd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=hid HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=idd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ilcd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ilnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ilsd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=innd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=insd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=iand HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=iasd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ksd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=kyed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=kywd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=laed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=lamd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=lawd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=med HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mdd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mad HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mied HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=miwd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=msnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mssd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=moed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mowd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mtd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ned HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nvd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nhd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=njd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nmd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nyed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nynd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nysd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nywd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nced HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ncmd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ncwd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ndd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ohnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ohsd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=oked HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=oknd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=okwd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ord HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=paed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=pamd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=pawd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=rid HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=scd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=sdd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=tned HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=tnmd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=tnwd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txsd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txwd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=utd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vtd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vaed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vawd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=waed HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wawd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wvnd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wvsd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wied HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wiwd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wyd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gud HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nmid HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=prd HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vid HTTP/1.1" 200 None

# %%
SEARCH_WARRANT_CSV_FN = 'search_warrants_model/search_warrants_all_districts_united_states_as_party.csv'
with open(SEARCH_WARRANT_CSV_FN, 'w') as csvfile:
    writer = None

    for i, district_court in district_courts.iterrows():
        search_results = get_documents_by_court(district_court["id"], party_name="united states")["results"]
        for result in search_results:
            if not writer:
                writer = csv.DictWriter(csvfile, fieldnames=result.keys())
                writer.writeheader()
            writer.writerow(result)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=dcd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=almd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=alnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=alsd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=akd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=azd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ared&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=arwd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=cacd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=caed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=cand&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=casd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=cod&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ctd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ded&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=flmd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=flnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=flsd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gamd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gand&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gasd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=hid&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=idd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ilcd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ilnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ilsd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=innd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=insd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=iand&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=iasd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ksd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=kyed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=kywd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=laed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=lamd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=lawd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=med&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mdd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mad&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mied&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=miwd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=msnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mssd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=moed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mowd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=mtd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ned&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nvd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nhd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=njd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nmd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nyed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nynd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nysd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nywd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nced&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ncmd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ncwd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ndd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ohnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ohsd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=oked&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=oknd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=okwd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=ord&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=paed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=pamd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=pawd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=rid&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=scd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=sdd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=tned&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=tnmd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=tnwd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txsd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=txwd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=utd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vtd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vaed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vawd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=waed&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wawd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wvnd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wvsd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wied&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wiwd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=wyd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=gud&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=nmid&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=prd&party_name=united+states HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.courtlistener.com:443
# DEBUG:urllib3.connectionpool:https://www.courtlistener.com:443 "GET /api/rest/v3/search/?type=r&order_by=entry_date_filed+desc&available_only=on&court=vid&party_name=united+states HTTP/1.1" 200 None

# %% [markdown]
# # getting RSS data
#
# for each court get 10 random document_types (code them no)
# and get 10 document_types that match 'warrant'

# %%
from sqlalchemy import create_engine
import pandas as pd
from os import environ
from dotenv import load_dotenv
load_dotenv()

live_engine = create_engine(environ.get("LIVE_DATABASE_URL"))


courts = pd.DataFrame(get_courts())
district_courts = courts[(~courts["fjc_court_id"].isna()) & (courts["fjc_court_id"] != '') & (courts["id"].str.match(r"[a-z]{2,3}d$"))]
district_courts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-34fc17e47306> in <module>
#       8
#       9
# ---> 10 courts = pd.DataFrame(get_courts())
#      11 district_courts = courts[(~courts["fjc_court_id"].isna()) & (courts["fjc_court_id"] != '') & (courts["id"].str.match(r"[a-z]{2,3}d$"))]
#      12 district_courts
#
# NameError: name 'get_courts' is not defined

# %%
# for each court, 


SEARCH_WARRANT_CSV_FN = 'search_warrants_model_training/rss_document_types_all_courts_random.csv'
with open(SEARCH_WARRANT_CSV_FN, 'w') as csvfile:
    writer = None

    for i, district_court in district_courts.iterrows():        
        search_results = pd.read_sql("""
            select case_name, document_type, case_number, court, false as "is search warrant?" from rss_docket_entries where document_type not ilike '%%warrant%%' and court = %(district_court)s order by random() limit 20;
            """, live_engine, params={"district_court": district_court["id"]}).head(20)
        for i, result in search_results.iterrows():
            if not writer:
                writer = csv.DictWriter(csvfile, fieldnames=result.to_dict().keys())
                writer.writeheader()
            writer.writerow(result.to_dict())


SEARCH_WARRANT_CSV_FN = 'search_warrants_model_training/rss_document_types_all_courts_matches_warrant.csv'
with open(SEARCH_WARRANT_CSV_FN, 'w') as csvfile:
    writer = None

    for i, district_court in district_courts.iterrows():
        search_results = pd.read_sql("""
            select case_name, document_type, case_number, court, null as "is search warrant?" from rss_docket_entries where document_type ilike '%%warrant%%' and court = %(district_court)s order by random() limit 20;
            """, live_engine, params={"district_court" : district_court["id"]}).head(20)
        for i, result in search_results.iterrows():
            if not writer:
                writer = csv.DictWriter(csvfile, fieldnames=result.to_dict().keys())
                writer.writeheader()
            writer.writerow(result.to_dict())

# %% [markdown]
# ## sw cases

# %%
pd.read_sql("""select court, count(*) from rss_docket_entries where substring(case_number, 6, 2) = 'sw' group by court""", live_engine)
# Out:
#   court  count
# 0   cod      6
# 1   dcd     16
# 2  mowd      6
# 3   rid     37

# %%
sw_docs = pd.read_sql("""select case_name,document_type,case_number,court, true as "is search warrant?" from rss_docket_entries where substring(case_number, 6, 2) = 'sw' or substring(case_number, 6, 2) = 'sc'""", live_engine)
sw_docs.to_csv("search_warrants_model_training/sw_docs.csv")
sw_docs
# Out:
#                                              case_name  \
# 0    INFORMATION ASSOCIATED WITH ONE ACCOUNT STORED...
# 1    USA v.  IN THE MATTER OF THE SEARCH OF THE PRE...
# 2    USA v. White iPhone with gray and blue case se...
# 3    USA v. IN THE MATTER OF THE SEARCH OF ONE CELL...
# 4    USA v. White iPhone with gray and blue case se...
# ..                                                 ...
# 96   THE MONITORING OF GLOBAL POSITIONING SYSTEM IN...
# 97   USA v. 4227 JENIFER STREET N.W. WASHINGTON, D....
# 98   USA v. A SILVER 2004 CHRYSLER TOWN AND COUNTRY...
# 99   THE MONITORING OF GLOBAL POSITIONING SYSTEM IN...
# 100  USA v. A SILVER 2004 CHRYSLER TOWN AND COUNTRY...
#
#                                          document_type      case_number court  \
# 0    Application for Search/Seizure Warrant- 18 U.S...    1:21-sc-01192   dcd
# 1                             Case Assigned/Reassigned  1:21-sw-00156-1   rid
# 2                             Case Assigned/Reassigned  1:21-sw-00154-1   rid
# 3                   Order on Motion to Unseal Document  1:21-sw-00052-1   dcd
# 4                              Application for Warrant  1:21-sw-00154-1   rid
# ..                                                 ...              ...   ...
# 96                      Order on Motion to Unseal Case    1:21-sc-00352   dcd
# 97        Search and Seizure Warrant Returned Executed  1:21-sw-00145-1   dcd
# 98        Search and Seizure Warrant Returned Executed  1:21-sw-00109-1   dcd
# 99                                       Case Unsealed    1:21-sc-00299   dcd
# 100                                      Case Unsealed  1:21-sw-00109-1   dcd
#
#      is search warrant?
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ..                  ...
# 96                 True
# 97                 True
# 98                 True
# 99                 True
# 100                True
#
# [101 rows x 5 columns]

# %% [markdown]
# # sw docs for NER data labeling
